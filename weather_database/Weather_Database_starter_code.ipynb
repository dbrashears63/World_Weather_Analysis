# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)            


# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})      
            
                 
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | grand gaube
# Processing Record 9 of Set 1 | weinan
# Processing Record 10 of Set 1 | cayenne
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | westport
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | amla
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | taltal
# Processing Record 20 of Set 1 | blagoyevo
# Processing Record 21 of Set 1 | severodvinsk
# Processing Record 22 of Set 1 | kodiak
# Processing Record 23 of Set 1 | gigmoto
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | dikson
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | sola
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | sao gabriel da cachoeira
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | kiama
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | san isidro
# Processing Record 37 of Set 1 | lorengau
# Processing Record 38 of Set 1 | sembakung
# Processing Record 39 of Set 1 | flinders
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | mbandaka
# Processing Record 44 of Set 1 | longyearbyen
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | port hueneme
# Processing Record 49 of Set 1 | kastrakion
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | qianjiang
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | mana
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | saint-pierre
# Processing Record 7 of Set 2 | tual
# Processing Record 8 of Set 2 | hornepayne
# Processing Record 9 of Set 2 | simao
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | prainha
# Processing Record 13 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 2 | uchiza
# Processing Record 15 of Set 2 | portland
# Processing Record 16 of Set 2 | fort nelson
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | emerald
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | havre-saint-pierre
# Processing Record 22 of Set 2 | labuhan
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | san quintin
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | soyo
# Processing Record 28 of Set 2 | saint-leu
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | liwale
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | humberto de campos
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | rocha
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | tigil
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | bambui
# Processing Record 40 of Set 2 | kudahuvadhoo
# Processing Record 41 of Set 2 | ibra
# Processing Record 42 of Set 2 | ilhabela
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | gorom-gorom
# Processing Record 47 of Set 2 | saint-fabien
# City not found. Skipping...
# Processing Record 48 of Set 2 | thompson
# Processing Record 49 of Set 2 | porto santo
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | kautokeino
# Processing Record 4 of Set 3 | ghanzi
# Processing Record 5 of Set 3 | ostrovnoy
# Processing Record 6 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 3 | savanur
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 3 | bonthe
# Processing Record 13 of Set 3 | saskylakh
# Processing Record 14 of Set 3 | usinsk
# Processing Record 15 of Set 3 | boende
# Processing Record 16 of Set 3 | hokitika
# Processing Record 17 of Set 3 | ust-kut
# Processing Record 18 of Set 3 | mayya
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | komsomolskiy
# Processing Record 21 of Set 3 | kavaratti
# Processing Record 22 of Set 3 | mopipi
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | dosso
# Processing Record 26 of Set 3 | morales
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | gasa
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | sabang
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | shingu
# Processing Record 34 of Set 3 | puerto baquerizo moreno
# Processing Record 35 of Set 3 | oriximina
# Processing Record 36 of Set 3 | shiyan
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | moranbah
# Processing Record 40 of Set 3 | krasnoyarskiy
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | kolokani
# Processing Record 43 of Set 3 | vila velha
# Processing Record 44 of Set 3 | torrington
# Processing Record 45 of Set 3 | chipinge
# Processing Record 46 of Set 3 | keetmanshoop
# Processing Record 47 of Set 3 | medina del campo
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | banepa
# Processing Record 1 of Set 4 | yulara
# Processing Record 2 of Set 4 | ahipara
# Processing Record 3 of Set 4 | inta
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | inverbervie
# Processing Record 6 of Set 4 | opuwo
# Processing Record 7 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 4 | katsina
# Processing Record 9 of Set 4 | bardiyah
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | nemuro
# Processing Record 12 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 4 | mount gambier
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | gat
# Processing Record 16 of Set 4 | quzhou
# Processing Record 17 of Set 4 | mayo
# Processing Record 18 of Set 4 | jalu
# Processing Record 19 of Set 4 | pyay
# Processing Record 20 of Set 4 | laguna
# Processing Record 21 of Set 4 | itapirapua
# Processing Record 22 of Set 4 | hollola
# Processing Record 23 of Set 4 | bartlesville
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | thap than
# Processing Record 26 of Set 4 | campina verde
# Processing Record 27 of Set 4 | male
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | suntar
# Processing Record 30 of Set 4 | bonavista
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | shakawe
# Processing Record 33 of Set 4 | purranque
# Processing Record 34 of Set 4 | kamina
# Processing Record 35 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | morgan city
# Processing Record 39 of Set 4 | liepaja
# Processing Record 40 of Set 4 | karratha
# Processing Record 41 of Set 4 | jiaojiang
# Processing Record 42 of Set 4 | sibolga
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | okhotsk
# Processing Record 45 of Set 4 | port keats
# Processing Record 46 of Set 4 | marzuq
# Processing Record 47 of Set 4 | shemonaikha
# Processing Record 48 of Set 4 | durg
# Processing Record 49 of Set 4 | porto tolle
# Processing Record 50 of Set 4 | richards bay
# Processing Record 1 of Set 5 | atasu
# Processing Record 2 of Set 5 | rosoman
# Processing Record 3 of Set 5 | belur
# Processing Record 4 of Set 5 | yangjiang
# Processing Record 5 of Set 5 | iranshahr
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | placido de castro
# Processing Record 8 of Set 5 | monastyrshchina
# Processing Record 9 of Set 5 | carnarvon
# Processing Record 10 of Set 5 | springbok
# Processing Record 11 of Set 5 | griffith
# Processing Record 12 of Set 5 | pangoa
# Processing Record 13 of Set 5 | vengerovo
# Processing Record 14 of Set 5 | ardakan
# Processing Record 15 of Set 5 | salym
# Processing Record 16 of Set 5 | balykshi
# Processing Record 17 of Set 5 | bahadurganj
# Processing Record 18 of Set 5 | daru
# Processing Record 19 of Set 5 | buena vista
# Processing Record 20 of Set 5 | anchorage
# Processing Record 21 of Set 5 | ballina
# Processing Record 22 of Set 5 | ancud
# Processing Record 23 of Set 5 | fairbanks
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | waipawa
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | hammond
# Processing Record 28 of Set 5 | sao jose da coroa grande
# Processing Record 29 of Set 5 | kiunga
# Processing Record 30 of Set 5 | avera
# Processing Record 31 of Set 5 | yandoon
# City not found. Skipping...
# Processing Record 32 of Set 5 | sitka
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | tyler
# Processing Record 36 of Set 5 | saint-georges
# Processing Record 37 of Set 5 | hilton head island
# Processing Record 38 of Set 5 | darhan
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | itapecerica
# Processing Record 41 of Set 5 | solnechnyy
# Processing Record 42 of Set 5 | aguada de pasajeros
# Processing Record 43 of Set 5 | kintampo
# Processing Record 44 of Set 5 | miri
# Processing Record 45 of Set 5 | oyama
# Processing Record 46 of Set 5 | sambava
# Processing Record 47 of Set 5 | batticaloa
# Processing Record 48 of Set 5 | njombe
# Processing Record 49 of Set 5 | waddan
# Processing Record 50 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 6 | iqaluit
# Processing Record 2 of Set 6 | ponta do sol
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | ixtapa
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | coihaique
# Processing Record 8 of Set 6 | mwinilunga
# Processing Record 9 of Set 6 | santa
# Processing Record 10 of Set 6 | madawaska
# Processing Record 11 of Set 6 | nenjiang
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | santa maria
# Processing Record 14 of Set 6 | emba
# Processing Record 15 of Set 6 | oranjemund
# Processing Record 16 of Set 6 | berlevag
# Processing Record 17 of Set 6 | hami
# Processing Record 18 of Set 6 | abay
# Processing Record 19 of Set 6 | leh
# Processing Record 20 of Set 6 | del pilar
# Processing Record 21 of Set 6 | outjo
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | tilichiki
# Processing Record 24 of Set 6 | molteno
# Processing Record 25 of Set 6 | urdoma
# Processing Record 26 of Set 6 | melilla
# Processing Record 27 of Set 6 | nouadhibou
# Processing Record 28 of Set 6 | lethem
# Processing Record 29 of Set 6 | lakes entrance
# Processing Record 30 of Set 6 | kieta
# Processing Record 31 of Set 6 | asau
# Processing Record 32 of Set 6 | torbay
# Processing Record 33 of Set 6 | tasiilaq
# Processing Record 34 of Set 6 | eydhafushi
# Processing Record 35 of Set 6 | svetlaya
# Processing Record 36 of Set 6 | soverato
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | esmeraldas
# Processing Record 39 of Set 6 | taoudenni
# Processing Record 40 of Set 6 | kaeo
# Processing Record 41 of Set 6 | cap-aux-meules
# Processing Record 42 of Set 6 | poum
# Processing Record 43 of Set 6 | port victoria
# Processing Record 44 of Set 6 | northam
# Processing Record 45 of Set 6 | parras
# City not found. Skipping...
# Processing Record 46 of Set 6 | russell
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | isangel
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | barwala
# Processing Record 1 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 2 of Set 7 | hovd
# Processing Record 3 of Set 7 | pajapan
# Processing Record 4 of Set 7 | geraldton
# Processing Record 5 of Set 7 | bandarbeyla
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 7 | cherdyn
# Processing Record 9 of Set 7 | gloucester
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | kilmez
# City not found. Skipping...
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | sobolevo
# Processing Record 14 of Set 7 | nanakuli
# Processing Record 15 of Set 7 | maldonado
# Processing Record 16 of Set 7 | castanos
# Processing Record 17 of Set 7 | panguna
# Processing Record 18 of Set 7 | aras
# Processing Record 19 of Set 7 | port hardy
# Processing Record 20 of Set 7 | olafsvik
# Processing Record 21 of Set 7 | sovetskiy
# Processing Record 22 of Set 7 | los llanos de aridane
# Processing Record 23 of Set 7 | margate
# Processing Record 24 of Set 7 | winnemucca
# Processing Record 25 of Set 7 | englewood
# Processing Record 26 of Set 7 | angelholm
# City not found. Skipping...
# Processing Record 27 of Set 7 | coromandel
# Processing Record 28 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 29 of Set 7 | mehamn
# Processing Record 30 of Set 7 | cherskiy
# Processing Record 31 of Set 7 | kahului
# Processing Record 32 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 7 | santa ines
# Processing Record 34 of Set 7 | ratnagiri
# Processing Record 35 of Set 7 | chumikan
# Processing Record 36 of Set 7 | granollers
# Processing Record 37 of Set 7 | sisimiut
# Processing Record 38 of Set 7 | rawson
# Processing Record 39 of Set 7 | constanza
# Processing Record 40 of Set 7 | bad durkheim
# Processing Record 41 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 7 | koslan
# Processing Record 43 of Set 7 | awjilah
# Processing Record 44 of Set 7 | norman wells
# Processing Record 45 of Set 7 | drovyanaya
# Processing Record 46 of Set 7 | nylstroom
# City not found. Skipping...
# Processing Record 47 of Set 7 | san patricio
# Processing Record 48 of Set 7 | port macquarie
# Processing Record 49 of Set 7 | ust-nera
# Processing Record 50 of Set 7 | rio cuarto
# Processing Record 1 of Set 8 | ambon
# Processing Record 2 of Set 8 | gizo
# Processing Record 3 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 4 of Set 8 | mareeba
# Processing Record 5 of Set 8 | narsaq
# Processing Record 6 of Set 8 | goundam
# Processing Record 7 of Set 8 | severomuysk
# Processing Record 8 of Set 8 | kudat
# Processing Record 9 of Set 8 | izazi
# Processing Record 10 of Set 8 | road town
# Processing Record 11 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | raga
# Processing Record 14 of Set 8 | port lincoln
# Processing Record 15 of Set 8 | cidreira
# Processing Record 16 of Set 8 | general bravo
# Processing Record 17 of Set 8 | havoysund
# Processing Record 18 of Set 8 | krasnoselkup
# Processing Record 19 of Set 8 | najran
# Processing Record 20 of Set 8 | batagay-alyta
# Processing Record 21 of Set 8 | caruray
# Processing Record 22 of Set 8 | salta
# Processing Record 23 of Set 8 | ola
# Processing Record 24 of Set 8 | pangnirtung
# Processing Record 25 of Set 8 | meulaboh
# Processing Record 26 of Set 8 | iralaya
# Processing Record 27 of Set 8 | hofn
# Processing Record 28 of Set 8 | chai badan
# Processing Record 29 of Set 8 | puerto el triunfo
# Processing Record 30 of Set 8 | nago
# Processing Record 31 of Set 8 | cairns
# Processing Record 32 of Set 8 | kingisepp
# Processing Record 33 of Set 8 | brigantine
# Processing Record 34 of Set 8 | koygorodok
# Processing Record 35 of Set 8 | miyako
# Processing Record 36 of Set 8 | pathein
# Processing Record 37 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 8 | vaatsa
# City not found. Skipping...
# Processing Record 39 of Set 8 | noumea
# Processing Record 40 of Set 8 | hulyaypole
# Processing Record 41 of Set 8 | magadan
# Processing Record 42 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 43 of Set 8 | high prairie
# Processing Record 44 of Set 8 | dryden
# Processing Record 45 of Set 8 | lalmohan
# Processing Record 46 of Set 8 | vestmanna
# Processing Record 47 of Set 8 | olenino
# Processing Record 48 of Set 8 | akyab
# Processing Record 49 of Set 8 | bilibino
# Processing Record 50 of Set 8 | amahai
# Processing Record 1 of Set 9 | jambi
# Processing Record 2 of Set 9 | mandera
# Processing Record 3 of Set 9 | troitskoye
# Processing Record 4 of Set 9 | husavik
# Processing Record 5 of Set 9 | nizhniy kuranakh
# Processing Record 6 of Set 9 | brae
# Processing Record 7 of Set 9 | belmonte
# Processing Record 8 of Set 9 | yuncheng
# Processing Record 9 of Set 9 | olinda
# Processing Record 10 of Set 9 | pitimbu
# Processing Record 11 of Set 9 | gazanjyk
# Processing Record 12 of Set 9 | plettenberg bay
# Processing Record 13 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 9 | koundara
# Processing Record 15 of Set 9 | pedini
# Processing Record 16 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 9 | chippewa falls
# Processing Record 18 of Set 9 | lerwick
# Processing Record 19 of Set 9 | arnedo
# Processing Record 20 of Set 9 | huinan
# Processing Record 21 of Set 9 | nykobing
# City not found. Skipping...
# Processing Record 22 of Set 9 | canar
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | asilah
# Processing Record 25 of Set 9 | gerede
# Processing Record 26 of Set 9 | gobabis
# Processing Record 27 of Set 9 | puerto madero
# Processing Record 28 of Set 9 | impfondo
# Processing Record 29 of Set 9 | sungaipenuh
# Processing Record 30 of Set 9 | anloga
# Processing Record 31 of Set 9 | sao filipe
# Processing Record 32 of Set 9 | raudeberg
# Processing Record 33 of Set 9 | komaki
# Processing Record 34 of Set 9 | hermagor
# Processing Record 35 of Set 9 | blackwater
# Processing Record 36 of Set 9 | gubkinskiy
# Processing Record 37 of Set 9 | panaba
# Processing Record 38 of Set 9 | gunnedah
# Processing Record 39 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 40 of Set 9 | mount isa
# Processing Record 41 of Set 9 | alofi
# Processing Record 42 of Set 9 | ribeira grande
# Processing Record 43 of Set 9 | hamilton
# Processing Record 44 of Set 9 | lamar
# Processing Record 45 of Set 9 | ilo
# Processing Record 46 of Set 9 | puerto narino
# Processing Record 47 of Set 9 | aasiaat
# Processing Record 48 of Set 9 | mudon
# Processing Record 49 of Set 9 | olavarria
# Processing Record 50 of Set 9 | albury
# Processing Record 1 of Set 10 | sindor
# Processing Record 2 of Set 10 | presidencia roque saenz pena
# Processing Record 3 of Set 10 | necochea
# Processing Record 4 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 10 | malinovoye ozero
# Processing Record 6 of Set 10 | ritchie
# Processing Record 7 of Set 10 | santa fe
# Processing Record 8 of Set 10 | cervo
# Processing Record 9 of Set 10 | shelburne
# Processing Record 10 of Set 10 | kalabagh
# Processing Record 11 of Set 10 | palauig
# Processing Record 12 of Set 10 | hagenow
# Processing Record 13 of Set 10 | torbat-e jam
# Processing Record 14 of Set 10 | gravdal
# Processing Record 15 of Set 10 | korla
# Processing Record 16 of Set 10 | qandala
# Processing Record 17 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 10 | saint anthony
# Processing Record 19 of Set 10 | kommunar
# Processing Record 20 of Set 10 | borda da mata
# Processing Record 21 of Set 10 | mnogovershinnyy
# Processing Record 22 of Set 10 | touros
# Processing Record 23 of Set 10 | porangatu
# Processing Record 24 of Set 10 | igarka
# Processing Record 25 of Set 10 | tazovskiy
# Processing Record 26 of Set 10 | erenhot
# Processing Record 27 of Set 10 | nyrob
# Processing Record 28 of Set 10 | burnie
# Processing Record 29 of Set 10 | la paz
# Processing Record 30 of Set 10 | bangkal
# Processing Record 31 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 10 | andenes
# Processing Record 33 of Set 10 | pemangkat
# Processing Record 34 of Set 10 | dunedin
# Processing Record 35 of Set 10 | visegrad
# Processing Record 36 of Set 10 | mastic beach
# Processing Record 37 of Set 10 | sechura
# Processing Record 38 of Set 10 | wapi pathum
# Processing Record 39 of Set 10 | tonj
# Processing Record 40 of Set 10 | vagur
# Processing Record 41 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 10 | nova olimpia
# Processing Record 43 of Set 10 | ust-tsilma
# Processing Record 44 of Set 10 | henties bay
# Processing Record 45 of Set 10 | grande-synthe
# Processing Record 46 of Set 10 | murray bridge
# Processing Record 47 of Set 10 | caldas novas
# Processing Record 48 of Set 10 | ondangwa
# Processing Record 49 of Set 10 | edd
# Processing Record 50 of Set 10 | shima
# Processing Record 1 of Set 11 | saquena
# Processing Record 2 of Set 11 | kalmunai
# Processing Record 3 of Set 11 | deputatskiy
# Processing Record 4 of Set 11 | balkanabat
# Processing Record 5 of Set 11 | yeppoon
# Processing Record 6 of Set 11 | phan thiet
# Processing Record 7 of Set 11 | toyooka
# Processing Record 8 of Set 11 | nabire
# Processing Record 9 of Set 11 | bondo
# Processing Record 10 of Set 11 | tyup
# Processing Record 11 of Set 11 | half moon bay
# Processing Record 12 of Set 11 | nishihara
# Processing Record 13 of Set 11 | zelenogradsk
# Processing Record 14 of Set 11 | sars
# Processing Record 15 of Set 11 | aklavik
# Processing Record 16 of Set 11 | banjar
# Processing Record 17 of Set 11 | bubaque
# Processing Record 18 of Set 11 | trinidad
# Processing Record 19 of Set 11 | lagoa
# Processing Record 20 of Set 11 | necocli
# Processing Record 21 of Set 11 | mago
# Processing Record 22 of Set 11 | atar
# Processing Record 23 of Set 11 | port blair
# Processing Record 24 of Set 11 | neder holluf
# Processing Record 25 of Set 11 | sakakah
# Processing Record 26 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 11 | tarhunah
# City not found. Skipping...
# Processing Record 28 of Set 11 | hualmay
# Processing Record 29 of Set 11 | las guacamayas
# Processing Record 30 of Set 11 | phonhong
# Processing Record 31 of Set 11 | novokizhinginsk
# Processing Record 32 of Set 11 | ibotirama
# Processing Record 33 of Set 11 | ribeira brava
# Processing Record 34 of Set 11 | mahebourg
# Processing Record 35 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 11 | pauini
# Processing Record 37 of Set 11 | begoro
# Processing Record 38 of Set 11 | anito
# Processing Record 39 of Set 11 | qui nhon
# Processing Record 40 of Set 11 | tateyama
# Processing Record 41 of Set 11 | kushiro
# Processing Record 42 of Set 11 | urumqi
# Processing Record 43 of Set 11 | formosa do rio preto
# Processing Record 44 of Set 11 | weihe
# Processing Record 45 of Set 11 | kushima
# Processing Record 46 of Set 11 | clarence town
# Processing Record 47 of Set 11 | boa vista
# Processing Record 48 of Set 11 | nelson bay
# Processing Record 49 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 50 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 12 | virginia beach
# Processing Record 2 of Set 12 | karachi
# Processing Record 3 of Set 12 | lamu
# Processing Record 4 of Set 12 | kasongo-lunda
# Processing Record 5 of Set 12 | taphan hin
# Processing Record 6 of Set 12 | yakeshi
# Processing Record 7 of Set 12 | cheney
# Processing Record 8 of Set 12 | rio de janeiro
# Processing Record 9 of Set 12 | saint-augustin
# Processing Record 10 of Set 12 | vilyuysk
# Processing Record 11 of Set 12 | mikkeli
# Processing Record 12 of Set 12 | muros
# Processing Record 13 of Set 12 | coburg
# Processing Record 14 of Set 12 | along
# Processing Record 15 of Set 12 | caucaia
# Processing Record 16 of Set 12 | lapithos
# Processing Record 17 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 12 | veraval
# Processing Record 20 of Set 12 | sandwick
# Processing Record 21 of Set 12 | itarema
# Processing Record 22 of Set 12 | finnsnes
# Processing Record 23 of Set 12 | san juan de los morros
# Processing Record 24 of Set 12 | soe
# Processing Record 25 of Set 12 | eureka
# Processing Record 26 of Set 12 | baykit
# Processing Record 27 of Set 12 | caracollo
# Processing Record 28 of Set 12 | sorong
# Processing Record 29 of Set 12 | broken hill
# Processing Record 30 of Set 12 | yar-sale
# Processing Record 31 of Set 12 | marsh harbour
# Processing Record 32 of Set 12 | scarborough
# Processing Record 33 of Set 12 | sassandra
# Processing Record 34 of Set 12 | suluq
# Processing Record 35 of Set 12 | dickinson
# Processing Record 36 of Set 12 | waingapu
# Processing Record 37 of Set 12 | jakar
# Processing Record 38 of Set 12 | itoman
# Processing Record 39 of Set 12 | litovko
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | oktyabrskoye
# Processing Record 42 of Set 12 | pak phanang
# Processing Record 43 of Set 12 | alindao
# Processing Record 44 of Set 12 | catuday
# Processing Record 45 of Set 12 | samarai
# Processing Record 46 of Set 12 | srandakan
# Processing Record 47 of Set 12 | codrington
# Processing Record 48 of Set 12 | marawi
# Processing Record 49 of Set 12 | hervey bay
# Processing Record 50 of Set 12 | ilulissat
# Processing Record 1 of Set 13 | sept-iles
# Processing Record 2 of Set 13 | nhulunbuy
# Processing Record 3 of Set 13 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 13 | florianopolis
# Processing Record 5 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 7 of Set 13 | neiafu
# Processing Record 8 of Set 13 | namibe
# Processing Record 9 of Set 13 | dali
# Processing Record 10 of Set 13 | xichang
# Processing Record 11 of Set 13 | egvekinot
# Processing Record 12 of Set 13 | redlands
# Processing Record 13 of Set 13 | nowogard
# Processing Record 14 of Set 13 | atbasar
# Processing Record 15 of Set 13 | bogorodskoye
# Processing Record 16 of Set 13 | ust-omchug
# Processing Record 17 of Set 13 | seymchan
# Processing Record 18 of Set 13 | karaton
# Processing Record 19 of Set 13 | totskoye
# Processing Record 20 of Set 13 | romny
# Processing Record 21 of Set 13 | tonantins
# Processing Record 22 of Set 13 | barra do corda
# Processing Record 23 of Set 13 | patitirion
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | zyryanka
# Processing Record 26 of Set 13 | tabou
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | san vicente
# Processing Record 29 of Set 13 | yabrud
# Processing Record 30 of Set 13 | rodrigues alves
# Processing Record 31 of Set 13 | haines junction
# Processing Record 32 of Set 13 | altamira
# Processing Record 33 of Set 13 | ofaqim
# Processing Record 34 of Set 13 | lompoc
# Processing Record 35 of Set 13 | naryan-mar
# Processing Record 36 of Set 13 | ambilobe
# Processing Record 37 of Set 13 | fare
# Processing Record 38 of Set 13 | mandvi
# Processing Record 39 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 13 | jumla
# Processing Record 41 of Set 13 | laiagam
# City not found. Skipping...
# Processing Record 42 of Set 13 | bedesa
# Processing Record 43 of Set 13 | khyriv
# Processing Record 44 of Set 13 | dobrun
# Processing Record 45 of Set 13 | ban nahin
# Processing Record 46 of Set 13 | vila franca do campo
# Processing Record 47 of Set 13 | ust-ishim
# Processing Record 48 of Set 13 | omboue
# Processing Record 49 of Set 13 | hinjilikatu
# Processing Record 50 of Set 13 | tari
# Processing Record 1 of Set 14 | takoradi
# Processing Record 2 of Set 14 | college
# Processing Record 3 of Set 14 | paamiut
# Processing Record 4 of Set 14 | kodinsk
# Processing Record 5 of Set 14 | athmallik
# Processing Record 6 of Set 14 | ville-marie
# Processing Record 7 of Set 14 | praia da vitoria
# Processing Record 8 of Set 14 | pimenta bueno
# Processing Record 9 of Set 14 | olden
# Processing Record 10 of Set 14 | sur
# Processing Record 11 of Set 14 | kaduna
# Processing Record 12 of Set 14 | chapais
# Processing Record 13 of Set 14 | atherton
# Processing Record 14 of Set 14 | ossora
# Processing Record 15 of Set 14 | dubbo
# Processing Record 16 of Set 14 | suarez
# Processing Record 17 of Set 14 | tigre
# Processing Record 18 of Set 14 | yuzhnyy
# Processing Record 19 of Set 14 | dwarka
# Processing Record 20 of Set 14 | pasni
# Processing Record 21 of Set 14 | innisfail
# Processing Record 22 of Set 14 | peno
# Processing Record 23 of Set 14 | guerrero negro
# Processing Record 24 of Set 14 | cambrils
# Processing Record 25 of Set 14 | gulf gate estates
# Processing Record 26 of Set 14 | nova olinda do norte
# Processing Record 27 of Set 14 | alice springs
# Processing Record 28 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 14 | turukhansk
# Processing Record 30 of Set 14 | alma
# Processing Record 31 of Set 14 | suzu
# City not found. Skipping...
# Processing Record 32 of Set 14 | santa cruz
# Processing Record 33 of Set 14 | buala
# Processing Record 34 of Set 14 | hay river
# Processing Record 35 of Set 14 | stornoway
# Processing Record 36 of Set 14 | aykhal
# Processing Record 37 of Set 14 | saint-francois
# Processing Record 38 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 14 | grenville
# Processing Record 40 of Set 14 | oudtshoorn
# Processing Record 41 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 14 | staryy nadym
# Processing Record 43 of Set 14 | adrar
# Processing Record 44 of Set 14 | kutum
# Processing Record 45 of Set 14 | stekolnyy
# City not found. Skipping...
# Processing Record 46 of Set 14 | mahibadhoo
# Processing Record 47 of Set 14 | puerto escondido
# Processing Record 48 of Set 14 | vanderhoof
# Processing Record 49 of Set 14 | honningsvag
# Processing Record 50 of Set 14 | laem sing
# Processing Record 1 of Set 15 | otane
# Processing Record 2 of Set 15 | mulanje
# Processing Record 3 of Set 15 | teya
# Processing Record 4 of Set 15 | dalby
# Processing Record 5 of Set 15 | yerbogachen
# Processing Record 6 of Set 15 | la palma del condado
# Processing Record 7 of Set 15 | havelock
# Processing Record 8 of Set 15 | bang saphan
# Processing Record 9 of Set 15 | stilfontein
# Processing Record 10 of Set 15 | aripuana
# Processing Record 11 of Set 15 | bani walid
# Processing Record 12 of Set 15 | thunder bay
# Processing Record 13 of Set 15 | maragogi
# Processing Record 14 of Set 15 | torres
# Processing Record 15 of Set 15 | solotcha
# Processing Record 16 of Set 15 | carutapera
# Processing Record 17 of Set 15 | coos bay
# Processing Record 18 of Set 15 | narasannapeta
# Processing Record 19 of Set 15 | sinnamary
# Processing Record 20 of Set 15 | aanekoski
# Processing Record 21 of Set 15 | nikitinskiy
# Processing Record 22 of Set 15 | alyangula
# Processing Record 23 of Set 15 | monteiro
# Processing Record 24 of Set 15 | frantiskovy lazne
# Processing Record 25 of Set 15 | camacupa
# Processing Record 26 of Set 15 | tecoanapa
# Processing Record 27 of Set 15 | adelaide
# Processing Record 28 of Set 15 | progreso
# Processing Record 29 of Set 15 | hirara
# Processing Record 30 of Set 15 | honavar
# Processing Record 31 of Set 15 | sorland
# Processing Record 32 of Set 15 | amapa
# Processing Record 33 of Set 15 | wladyslawowo
# Processing Record 34 of Set 15 | rafai
# Processing Record 35 of Set 15 | chara
# Processing Record 36 of Set 15 | lagunas
# Processing Record 37 of Set 15 | tucumcari
# Processing Record 38 of Set 15 | vrangel
# Processing Record 39 of Set 15 | bull savanna
# Processing Record 40 of Set 15 | wonthaggi
# Processing Record 41 of Set 15 | ferme-neuve
# Processing Record 42 of Set 15 | aksarka
# Processing Record 43 of Set 15 | haapiti
# Processing Record 44 of Set 15 | baiao
# Processing Record 45 of Set 15 | safita
# Processing Record 46 of Set 15 | santa helena de goias
# Processing Record 47 of Set 15 | paraiso
# Processing Record 48 of Set 15 | phek
# Processing Record 49 of Set 15 | benguela
# Processing Record 50 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 16 | kaka
# Processing Record 2 of Set 16 | goure
# Processing Record 3 of Set 16 | ucluelet
# Processing Record 4 of Set 16 | egyek
# Processing Record 5 of Set 16 | gazojak
# Processing Record 6 of Set 16 | conakry
# Processing Record 7 of Set 16 | christchurch
# Processing Record 8 of Set 16 | isiro
# Processing Record 9 of Set 16 | tungkang
# City not found. Skipping...
# Processing Record 10 of Set 16 | moose factory
# Processing Record 11 of Set 16 | effingham
# Processing Record 12 of Set 16 | umm kaddadah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 703

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Castro      BR -24.7911  -50.0119     78.42        54          94
# 1         Hilo      US  19.7297 -155.0900     78.53        74          20
# 2       Barrow      US  71.2906 -156.7887     21.22        68         100
# 3   Georgetown      MY   5.4112  100.3354     80.24        90          40
# 4    Esperance      AU -33.8667  121.9000     55.71        67         100
# 5     Klaksvik      FO  62.2266   -6.5890     50.92        94          59
# 6   Chokurdakh      RU  70.6333  147.9167    -31.23       100          90
# 7  Grand Gaube      MU -20.0064   57.6608     72.37        69           0
# 8       Weinan      CN  34.5036  109.5089     47.75        50          20
# 9      Cayenne      GF   4.9333  -52.3333     82.44        78          75
#
#    Wind Speed Current Description
# 0        8.25     overcast clouds
# 1        8.05          few clouds
# 2       16.11     overcast clouds
# 3        1.14    scattered clouds
# 4        7.78     overcast clouds
# 5       13.56       broken clouds
# 6        5.12     overcast clouds
# 7        3.00           clear sky
# 8        3.09          few clouds
# 9       10.36       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df= city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()

# Recreate the DataFrame by using the new column order
city_data_df = pd.DataFrame(city_data)

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Castro      BR -24.7911  -50.0119     78.42        54          94
# 1         Hilo      US  19.7297 -155.0900     78.53        74          20
# 2       Barrow      US  71.2906 -156.7887     21.22        68         100
# 3   Georgetown      MY   5.4112  100.3354     80.24        90          40
# 4    Esperance      AU -33.8667  121.9000     55.71        67         100
# 5     Klaksvik      FO  62.2266   -6.5890     50.92        94          59
# 6   Chokurdakh      RU  70.6333  147.9167    -31.23       100          90
# 7  Grand Gaube      MU -20.0064   57.6608     72.37        69           0
# 8       Weinan      CN  34.5036  109.5089     47.75        50          20
# 9      Cayenne      GF   4.9333  -52.3333     82.44        78          75
#
#    Wind Speed Current Description
# 0        8.25     overcast clouds
# 1        8.05          few clouds
# 2       16.11     overcast clouds
# 3        1.14    scattered clouds
# 4        7.78     overcast clouds
# 5       13.56       broken clouds
# 6        5.12     overcast clouds
# 7        3.00           clear sky
# 8        3.09          few clouds
# 9       10.36       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
