# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)            


# Print the city count to confirm sufficient count
len(cities)
# Out:
# 784

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_description})      
            
                 
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | aleksandrovskiy zavod
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | kahului
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bambanglipuro
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | baykit
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | altay
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | lima
# Processing Record 20 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | luganville
# Processing Record 24 of Set 1 | itarema
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | teseney
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | alofi
# Processing Record 35 of Set 1 | bajil
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 1 | kalakamati
# Processing Record 39 of Set 1 | phanom sarakham
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | fallon
# Processing Record 45 of Set 1 | shahapur
# Processing Record 46 of Set 1 | gizo
# Processing Record 47 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 48 of Set 1 | homer
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | gejiu
# Processing Record 2 of Set 2 | dukat
# Processing Record 3 of Set 2 | buford
# Processing Record 4 of Set 2 | loralai
# Processing Record 5 of Set 2 | cherskiy
# Processing Record 6 of Set 2 | malabuyoc
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | mbandaka
# Processing Record 9 of Set 2 | zyryanka
# Processing Record 10 of Set 2 | andenes
# Processing Record 11 of Set 2 | suntar
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | bulgan
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | yerofey pavlovich
# Processing Record 16 of Set 2 | sakakah
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | lasa
# Processing Record 20 of Set 2 | yar-sale
# Processing Record 21 of Set 2 | freistadt
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | tessalit
# Processing Record 24 of Set 2 | beringovskiy
# Processing Record 25 of Set 2 | cabo san lucas
# Processing Record 26 of Set 2 | swellendam
# Processing Record 27 of Set 2 | sal rei
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | acurenam
# Processing Record 30 of Set 2 | januaria
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | orange walk
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | galesong
# Processing Record 36 of Set 2 | kawalu
# Processing Record 37 of Set 2 | muros
# Processing Record 38 of Set 2 | tecoanapa
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | danielskuil
# Processing Record 41 of Set 2 | cabedelo
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | altamira
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | saint-pierre
# Processing Record 47 of Set 2 | kambove
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | clovis
# Processing Record 1 of Set 3 | lososina
# Processing Record 2 of Set 3 | olinda
# Processing Record 3 of Set 3 | kulhudhuffushi
# Processing Record 4 of Set 3 | araouane
# Processing Record 5 of Set 3 | tura
# Processing Record 6 of Set 3 | bakchar
# Processing Record 7 of Set 3 | college
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | kavieng
# Processing Record 10 of Set 3 | mar del plata
# Processing Record 11 of Set 3 | cap malheureux
# Processing Record 12 of Set 3 | nizhniy baskunchak
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | saskylakh
# Processing Record 15 of Set 3 | lake havasu city
# Processing Record 16 of Set 3 | klyuchi
# Processing Record 17 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 3 | pangnirtung
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | okandja
# City not found. Skipping...
# Processing Record 21 of Set 3 | hualmay
# Processing Record 22 of Set 3 | balikpapan
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | barguzin
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | teahupoo
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | ilulissat
# Processing Record 32 of Set 3 | te anau
# Processing Record 33 of Set 3 | honiara
# Processing Record 34 of Set 3 | banda aceh
# Processing Record 35 of Set 3 | sorland
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | ongole
# Processing Record 40 of Set 3 | mahanje
# Processing Record 41 of Set 3 | warrington
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | dourbali
# Processing Record 44 of Set 3 | kruisfontein
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | teneguiban
# City not found. Skipping...
# Processing Record 47 of Set 3 | bafoulabe
# Processing Record 48 of Set 3 | niteroi
# Processing Record 49 of Set 3 | igrim
# Processing Record 50 of Set 3 | koungou
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | lata
# Processing Record 4 of Set 4 | berdigestyakh
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | port-gentil
# Processing Record 7 of Set 4 | kloulklubed
# Processing Record 8 of Set 4 | qaqortoq
# Processing Record 9 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 4 | rudnogorsk
# Processing Record 11 of Set 4 | chaozhou
# Processing Record 12 of Set 4 | kattivakkam
# Processing Record 13 of Set 4 | cape town
# Processing Record 14 of Set 4 | richards bay
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | oloron-sainte-marie
# Processing Record 17 of Set 4 | ifanadiana
# Processing Record 18 of Set 4 | pringsewu
# Processing Record 19 of Set 4 | oktyabrskoye
# Processing Record 20 of Set 4 | marzuq
# Processing Record 21 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 4 | kapit
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | amta
# Processing Record 25 of Set 4 | sarangani
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | thoen
# Processing Record 28 of Set 4 | charters towers
# Processing Record 29 of Set 4 | brigantine
# Processing Record 30 of Set 4 | krasnyy yar
# Processing Record 31 of Set 4 | neiafu
# Processing Record 32 of Set 4 | skala
# Processing Record 33 of Set 4 | takoradi
# Processing Record 34 of Set 4 | uray
# Processing Record 35 of Set 4 | nouadhibou
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | shanghai
# Processing Record 38 of Set 4 | narsaq
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | ucluelet
# Processing Record 41 of Set 4 | kurilsk
# Processing Record 42 of Set 4 | constitucion
# Processing Record 43 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | cadillac
# Processing Record 48 of Set 4 | mount isa
# Processing Record 49 of Set 4 | ashland
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | jawhar
# Processing Record 2 of Set 5 | bud
# Processing Record 3 of Set 5 | kudat
# Processing Record 4 of Set 5 | vikhorevka
# Processing Record 5 of Set 5 | shimoda
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | la asuncion
# Processing Record 8 of Set 5 | mikhaylov
# Processing Record 9 of Set 5 | evansville
# Processing Record 10 of Set 5 | touros
# Processing Record 11 of Set 5 | shahrud
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | chenghai
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | vestmanna
# Processing Record 17 of Set 5 | les cayes
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | chaman
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | kjollefjord
# Processing Record 24 of Set 5 | mirnyy
# Processing Record 25 of Set 5 | porto novo
# Processing Record 26 of Set 5 | broome
# Processing Record 27 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 5 | maragogi
# Processing Record 29 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 5 | santa cruz del sur
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | leningradskiy
# Processing Record 33 of Set 5 | shaunavon
# Processing Record 34 of Set 5 | tres picos
# Processing Record 35 of Set 5 | kulunda
# Processing Record 36 of Set 5 | miandrivazo
# Processing Record 37 of Set 5 | bethel
# Processing Record 38 of Set 5 | belogorsk
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | ushtobe
# Processing Record 41 of Set 5 | surt
# Processing Record 42 of Set 5 | esso
# Processing Record 43 of Set 5 | torbay
# Processing Record 44 of Set 5 | moron
# Processing Record 45 of Set 5 | porto walter
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | embonas
# Processing Record 48 of Set 5 | biltine
# Processing Record 49 of Set 5 | naze
# Processing Record 50 of Set 5 | cairns
# Processing Record 1 of Set 6 | maniitsoq
# Processing Record 2 of Set 6 | santarem
# Processing Record 3 of Set 6 | alekseyevka
# Processing Record 4 of Set 6 | shitkino
# Processing Record 5 of Set 6 | katsuura
# Processing Record 6 of Set 6 | valasske klobouky
# Processing Record 7 of Set 6 | harrisonburg
# Processing Record 8 of Set 6 | tougue
# Processing Record 9 of Set 6 | sitka
# Processing Record 10 of Set 6 | coquimbo
# Processing Record 11 of Set 6 | esperance
# Processing Record 12 of Set 6 | ambovombe
# Processing Record 13 of Set 6 | lengshuitan
# Processing Record 14 of Set 6 | east london
# Processing Record 15 of Set 6 | wyszkow
# Processing Record 16 of Set 6 | mayo
# Processing Record 17 of Set 6 | huarmey
# Processing Record 18 of Set 6 | salamiyah
# Processing Record 19 of Set 6 | laguna
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | morgan city
# Processing Record 24 of Set 6 | saint-augustin
# Processing Record 25 of Set 6 | staryy nadym
# Processing Record 26 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 6 | chernyshevskiy
# Processing Record 28 of Set 6 | makakilo city
# Processing Record 29 of Set 6 | sumbe
# Processing Record 30 of Set 6 | yelizovo
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | biak
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | aklavik
# Processing Record 35 of Set 6 | vestmannaeyjar
# Processing Record 36 of Set 6 | haines junction
# Processing Record 37 of Set 6 | lubbock
# Processing Record 38 of Set 6 | vostok
# Processing Record 39 of Set 6 | havoysund
# Processing Record 40 of Set 6 | evanston
# Processing Record 41 of Set 6 | santa maria
# Processing Record 42 of Set 6 | birao
# Processing Record 43 of Set 6 | vila
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | krasnoarmeyskiy
# Processing Record 46 of Set 6 | rio rancho
# Processing Record 47 of Set 6 | alice springs
# Processing Record 48 of Set 6 | tonj
# Processing Record 49 of Set 6 | lorengau
# Processing Record 50 of Set 6 | sioux lookout
# Processing Record 1 of Set 7 | yulara
# Processing Record 2 of Set 7 | genhe
# Processing Record 3 of Set 7 | moctezuma
# Processing Record 4 of Set 7 | barranca
# Processing Record 5 of Set 7 | xai-xai
# Processing Record 6 of Set 7 | nome
# Processing Record 7 of Set 7 | dumas
# Processing Record 8 of Set 7 | marshall
# Processing Record 9 of Set 7 | taltal
# Processing Record 10 of Set 7 | khandyga
# Processing Record 11 of Set 7 | korla
# Processing Record 12 of Set 7 | leo
# Processing Record 13 of Set 7 | erdaojiang
# Processing Record 14 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 7 | thompson
# Processing Record 16 of Set 7 | teregova
# Processing Record 17 of Set 7 | kluang
# Processing Record 18 of Set 7 | yuanping
# Processing Record 19 of Set 7 | ahipara
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | denpasar
# Processing Record 22 of Set 7 | kuryk
# Processing Record 23 of Set 7 | da lat
# Processing Record 24 of Set 7 | malaga
# Processing Record 25 of Set 7 | redlands
# Processing Record 26 of Set 7 | tautira
# Processing Record 27 of Set 7 | meulaboh
# Processing Record 28 of Set 7 | tarrega
# Processing Record 29 of Set 7 | dicabisagan
# Processing Record 30 of Set 7 | mapiripan
# Processing Record 31 of Set 7 | deputatskiy
# Processing Record 32 of Set 7 | cordoba
# Processing Record 33 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 7 | hamilton
# Processing Record 36 of Set 7 | toba
# Processing Record 37 of Set 7 | luwuk
# Processing Record 38 of Set 7 | gewane
# Processing Record 39 of Set 7 | port-cartier
# Processing Record 40 of Set 7 | usinsk
# Processing Record 41 of Set 7 | guerrero negro
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | silver city
# Processing Record 45 of Set 7 | sokolovyy
# Processing Record 46 of Set 7 | shache
# Processing Record 47 of Set 7 | hasaki
# Processing Record 48 of Set 7 | wajima
# Processing Record 49 of Set 7 | ketchikan
# Processing Record 50 of Set 7 | mackenzie
# Processing Record 1 of Set 8 | ponta delgada
# Processing Record 2 of Set 8 | waingapu
# Processing Record 3 of Set 8 | nantucket
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | vardo
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | ballina
# Processing Record 8 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 8 | sao joao da barra
# Processing Record 10 of Set 8 | beloha
# Processing Record 11 of Set 8 | padang
# Processing Record 12 of Set 8 | codrington
# Processing Record 13 of Set 8 | oga
# Processing Record 14 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 8 | viedma
# Processing Record 16 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | kisangani
# Processing Record 18 of Set 8 | imbituba
# Processing Record 19 of Set 8 | christchurch
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | effingham
# Processing Record 23 of Set 8 | winnemucca
# Processing Record 24 of Set 8 | orgun
# City not found. Skipping...
# Processing Record 25 of Set 8 | kysyl-syr
# Processing Record 26 of Set 8 | dhidhdhoo
# Processing Record 27 of Set 8 | chiredzi
# Processing Record 28 of Set 8 | ascope
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 31 of Set 8 | madimba
# Processing Record 32 of Set 8 | kamenka
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | oistins
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | faanui
# Processing Record 37 of Set 8 | lusambo
# Processing Record 38 of Set 8 | vaasa
# Processing Record 39 of Set 8 | greencastle
# Processing Record 40 of Set 8 | dakar
# Processing Record 41 of Set 8 | zhigansk
# Processing Record 42 of Set 8 | chicama
# Processing Record 43 of Set 8 | mombetsu
# Processing Record 44 of Set 8 | nador
# Processing Record 45 of Set 8 | mogok
# Processing Record 46 of Set 8 | srbobran
# Processing Record 47 of Set 8 | kayerkan
# Processing Record 48 of Set 8 | karratha
# Processing Record 49 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 8 | gamba
# Processing Record 1 of Set 9 | sabang
# Processing Record 2 of Set 9 | provost
# Processing Record 3 of Set 9 | jalu
# Processing Record 4 of Set 9 | pemangkat
# Processing Record 5 of Set 9 | mount gambier
# Processing Record 6 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 9 | necochea
# Processing Record 8 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 9 of Set 9 | birjand
# Processing Record 10 of Set 9 | villa bruzual
# Processing Record 11 of Set 9 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | carballo
# Processing Record 13 of Set 9 | maldonado
# Processing Record 14 of Set 9 | sussex
# Processing Record 15 of Set 9 | bandarbeyla
# Processing Record 16 of Set 9 | poum
# Processing Record 17 of Set 9 | nabire
# Processing Record 18 of Set 9 | olden
# Processing Record 19 of Set 9 | fengrun
# Processing Record 20 of Set 9 | sinnamary
# Processing Record 21 of Set 9 | kormend
# Processing Record 22 of Set 9 | thunder bay
# Processing Record 23 of Set 9 | kushima
# Processing Record 24 of Set 9 | muroto
# Processing Record 25 of Set 9 | rawlins
# Processing Record 26 of Set 9 | verkh-suetka
# Processing Record 27 of Set 9 | lander
# Processing Record 28 of Set 9 | tuatapere
# Processing Record 29 of Set 9 | northam
# Processing Record 30 of Set 9 | douentza
# Processing Record 31 of Set 9 | solnechnyy
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | fuerte olimpo
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | pervoye maya
# Processing Record 36 of Set 9 | odienne
# Processing Record 37 of Set 9 | rapid valley
# Processing Record 38 of Set 9 | clyde river
# Processing Record 39 of Set 9 | luderitz
# Processing Record 40 of Set 9 | stolin
# Processing Record 41 of Set 9 | grindavik
# Processing Record 42 of Set 9 | virginia beach
# Processing Record 43 of Set 9 | salalah
# Processing Record 44 of Set 9 | muisne
# Processing Record 45 of Set 9 | lesnoye
# Processing Record 46 of Set 9 | sinj
# Processing Record 47 of Set 9 | roald
# Processing Record 48 of Set 9 | amapa
# Processing Record 49 of Set 9 | comodoro rivadavia
# Processing Record 50 of Set 9 | peleduy
# Processing Record 1 of Set 10 | carlagan
# Processing Record 2 of Set 10 | ailigandi
# Processing Record 3 of Set 10 | katherine
# Processing Record 4 of Set 10 | poltavka
# Processing Record 5 of Set 10 | raudeberg
# Processing Record 6 of Set 10 | kiunga
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 9 of Set 10 | luau
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | espinosa
# Processing Record 12 of Set 10 | westport
# Processing Record 13 of Set 10 | klaksvik
# Processing Record 14 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 17 of Set 10 | camacha
# Processing Record 18 of Set 10 | balkanabat
# Processing Record 19 of Set 10 | qasigiannguit
# Processing Record 20 of Set 10 | cody
# Processing Record 21 of Set 10 | todos santos
# Processing Record 22 of Set 10 | tabou
# Processing Record 23 of Set 10 | micheweni
# Processing Record 24 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 10 | kapoeta
# Processing Record 26 of Set 10 | erhlin
# City not found. Skipping...
# Processing Record 27 of Set 10 | krasnoselkup
# Processing Record 28 of Set 10 | saint-francois
# Processing Record 29 of Set 10 | troitskoye
# Processing Record 30 of Set 10 | karpathos
# Processing Record 31 of Set 10 | guarapari
# Processing Record 32 of Set 10 | la macarena
# Processing Record 33 of Set 10 | angola
# Processing Record 34 of Set 10 | mehamn
# Processing Record 35 of Set 10 | ussel
# Processing Record 36 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 37 of Set 10 | molina
# Processing Record 38 of Set 10 | grants pass
# Processing Record 39 of Set 10 | shingu
# Processing Record 40 of Set 10 | mahibadhoo
# Processing Record 41 of Set 10 | podgornoye
# Processing Record 42 of Set 10 | black river
# Processing Record 43 of Set 10 | kosh-agach
# Processing Record 44 of Set 10 | ust-maya
# Processing Record 45 of Set 10 | balabac
# Processing Record 46 of Set 10 | yerbogachen
# Processing Record 47 of Set 10 | robertsport
# Processing Record 48 of Set 10 | castro
# Processing Record 49 of Set 10 | veraval
# Processing Record 50 of Set 10 | saint anthony
# Processing Record 1 of Set 11 | ulladulla
# Processing Record 2 of Set 11 | ormond beach
# Processing Record 3 of Set 11 | canutama
# Processing Record 4 of Set 11 | aasiaat
# Processing Record 5 of Set 11 | hastings
# Processing Record 6 of Set 11 | tamale
# Processing Record 7 of Set 11 | yazman
# Processing Record 8 of Set 11 | poya
# Processing Record 9 of Set 11 | voyvozh
# Processing Record 10 of Set 11 | natal
# Processing Record 11 of Set 11 | aswan
# Processing Record 12 of Set 11 | pochutla
# Processing Record 13 of Set 11 | san carlos de bariloche
# Processing Record 14 of Set 11 | lavumisa
# Processing Record 15 of Set 11 | alugan
# Processing Record 16 of Set 11 | amahai
# Processing Record 17 of Set 11 | tabuk
# Processing Record 18 of Set 11 | creston
# Processing Record 19 of Set 11 | sistranda
# Processing Record 20 of Set 11 | de-kastri
# Processing Record 21 of Set 11 | obo
# Processing Record 22 of Set 11 | khani
# Processing Record 23 of Set 11 | krasnovishersk
# Processing Record 24 of Set 11 | byron bay
# Processing Record 25 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 26 of Set 11 | xuddur
# Processing Record 27 of Set 11 | nelson bay
# Processing Record 28 of Set 11 | kasongo-lunda
# Processing Record 29 of Set 11 | archidona
# Processing Record 30 of Set 11 | garden city
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | ponta do sol
# Processing Record 33 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 11 | los llanos de aridane
# Processing Record 36 of Set 11 | coruripe
# Processing Record 37 of Set 11 | ottawa
# Processing Record 38 of Set 11 | maua
# Processing Record 39 of Set 11 | tilichiki
# Processing Record 40 of Set 11 | kokkola
# Processing Record 41 of Set 11 | sinjai
# Processing Record 42 of Set 11 | victoriaville
# Processing Record 43 of Set 11 | gorontalo
# Processing Record 44 of Set 11 | mogwase
# Processing Record 45 of Set 11 | skjervoy
# Processing Record 46 of Set 11 | tarsus
# Processing Record 47 of Set 11 | geraldton
# Processing Record 48 of Set 11 | abu dhabi
# Processing Record 49 of Set 11 | lerwick
# Processing Record 50 of Set 11 | marquette
# Processing Record 1 of Set 12 | nalut
# Processing Record 2 of Set 12 | hambantota
# Processing Record 3 of Set 12 | umea
# Processing Record 4 of Set 12 | eureka
# Processing Record 5 of Set 12 | auki
# Processing Record 6 of Set 12 | ous
# Processing Record 7 of Set 12 | gushikawa
# Processing Record 8 of Set 12 | the valley
# Processing Record 9 of Set 12 | buckeye
# Processing Record 10 of Set 12 | caledonia
# Processing Record 11 of Set 12 | jatai
# Processing Record 12 of Set 12 | southbridge
# Processing Record 13 of Set 12 | bulancak
# Processing Record 14 of Set 12 | port lincoln
# Processing Record 15 of Set 12 | weligama
# Processing Record 16 of Set 12 | mangrol
# Processing Record 17 of Set 12 | shelabolikha
# Processing Record 18 of Set 12 | riverton
# Processing Record 19 of Set 12 | platanos
# Processing Record 20 of Set 12 | fare
# Processing Record 21 of Set 12 | bilibino
# Processing Record 22 of Set 12 | leshukonskoye
# Processing Record 23 of Set 12 | erdenet
# Processing Record 24 of Set 12 | guerrero
# Processing Record 25 of Set 12 | praia da vitoria
# Processing Record 26 of Set 12 | dwarka
# Processing Record 27 of Set 12 | pandan
# Processing Record 28 of Set 12 | mugur-aksy
# Processing Record 29 of Set 12 | gotsu
# Processing Record 30 of Set 12 | espanola
# Processing Record 31 of Set 12 | tual
# Processing Record 32 of Set 12 | bam
# Processing Record 33 of Set 12 | buluang
# Processing Record 34 of Set 12 | benguela
# Processing Record 35 of Set 12 | sovetskiy
# Processing Record 36 of Set 12 | beaverlodge
# Processing Record 37 of Set 12 | roura
# Processing Record 38 of Set 12 | goderich
# Processing Record 39 of Set 12 | kalawit
# Processing Record 40 of Set 12 | colares
# Processing Record 41 of Set 12 | bonthe
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | seymchan
# Processing Record 44 of Set 12 | gao
# Processing Record 45 of Set 12 | puerto penasco
# Processing Record 46 of Set 12 | manta
# Processing Record 47 of Set 12 | kirakira
# Processing Record 48 of Set 12 | lixourion
# Processing Record 49 of Set 12 | ishigaki
# Processing Record 50 of Set 12 | bitung
# Processing Record 1 of Set 13 | kusti
# Processing Record 2 of Set 13 | sri aman
# Processing Record 3 of Set 13 | santa lucia
# Processing Record 4 of Set 13 | zemio
# Processing Record 5 of Set 13 | mayumba
# Processing Record 6 of Set 13 | alushta
# Processing Record 7 of Set 13 | eregli
# Processing Record 8 of Set 13 | andros town
# Processing Record 9 of Set 13 | ust-nera
# Processing Record 10 of Set 13 | winsum
# Processing Record 11 of Set 13 | eirunepe
# Processing Record 12 of Set 13 | sarwar
# Processing Record 13 of Set 13 | shepsi
# Processing Record 14 of Set 13 | la ronge
# Processing Record 15 of Set 13 | timra
# Processing Record 16 of Set 13 | pujehun
# Processing Record 17 of Set 13 | khalkhal
# Processing Record 18 of Set 13 | soyo
# Processing Record 19 of Set 13 | lisala
# Processing Record 20 of Set 13 | changping
# Processing Record 21 of Set 13 | nuoro
# Processing Record 22 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 23 of Set 13 | tanshui
# City not found. Skipping...
# Processing Record 24 of Set 13 | siimusti
# Processing Record 25 of Set 13 | talaya
# Processing Record 26 of Set 13 | carhuaz
# Processing Record 27 of Set 13 | araguatins
# City not found. Skipping...
# Processing Record 28 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 29 of Set 13 | rio de janeiro
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | mnogovershinnyy
# Processing Record 32 of Set 13 | sendafa
# Processing Record 33 of Set 13 | marica
# Processing Record 34 of Set 13 | khash
# Processing Record 35 of Set 13 | panjab
# Processing Record 36 of Set 13 | tolaga bay
# Processing Record 37 of Set 13 | ngunguru
# Processing Record 38 of Set 13 | the pas
# Processing Record 39 of Set 13 | alta floresta
# Processing Record 40 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 13 | arco
# Processing Record 42 of Set 13 | riyadh
# Processing Record 43 of Set 13 | lincoln
# Processing Record 44 of Set 13 | puerto baquerizo moreno
# Processing Record 45 of Set 13 | coihaique
# Processing Record 46 of Set 13 | suna
# Processing Record 47 of Set 13 | bon accord
# Processing Record 48 of Set 13 | opuwo
# Processing Record 49 of Set 13 | kununurra
# Processing Record 50 of Set 13 | tigil
# Processing Record 1 of Set 14 | hornepayne
# Processing Record 2 of Set 14 | mokobeng
# Processing Record 3 of Set 14 | bosaso
# Processing Record 4 of Set 14 | broken hill
# Processing Record 5 of Set 14 | maraba
# Processing Record 6 of Set 14 | tres arroyos
# Processing Record 7 of Set 14 | ljubljana
# Processing Record 8 of Set 14 | nicoya
# Processing Record 9 of Set 14 | bolu
# Processing Record 10 of Set 14 | osorno
# Processing Record 11 of Set 14 | north bend
# Processing Record 12 of Set 14 | nampula
# Processing Record 13 of Set 14 | kiama
# Processing Record 14 of Set 14 | batesville
# Processing Record 15 of Set 14 | shaoyang
# Processing Record 16 of Set 14 | vieques
# Processing Record 17 of Set 14 | mazamari
# Processing Record 18 of Set 14 | timiryazevskiy
# Processing Record 19 of Set 14 | aksarka
# Processing Record 20 of Set 14 | fandriana
# Processing Record 21 of Set 14 | ugoofaaru
# Processing Record 22 of Set 14 | daru
# Processing Record 23 of Set 14 | haimen
# Processing Record 24 of Set 14 | yumen
# Processing Record 25 of Set 14 | changji
# Processing Record 26 of Set 14 | penzance
# Processing Record 27 of Set 14 | rundu
# Processing Record 28 of Set 14 | ler
# Processing Record 29 of Set 14 | azrow
# City not found. Skipping...
# Processing Record 30 of Set 14 | nago
# Processing Record 31 of Set 14 | miri
# Processing Record 32 of Set 14 | phonhong
# Processing Record 33 of Set 14 | samtredia
# Processing Record 34 of Set 14 | don sak
# Processing Record 35 of Set 14 | yenagoa
# Processing Record 36 of Set 14 | sringeri
# Processing Record 37 of Set 14 | porto torres
# Processing Record 38 of Set 14 | komagane
# Processing Record 39 of Set 14 | donduseni
# Processing Record 40 of Set 14 | ormara
# Processing Record 41 of Set 14 | divnogorsk
# Processing Record 42 of Set 14 | maningrida
# Processing Record 43 of Set 14 | villa rica
# Processing Record 44 of Set 14 | beipiao
# Processing Record 45 of Set 14 | tazovskiy
# Processing Record 46 of Set 14 | saint-georges
# Processing Record 47 of Set 14 | niksar
# Processing Record 48 of Set 14 | arman
# Processing Record 49 of Set 14 | irbil
# Processing Record 50 of Set 14 | ajdabiya
# Processing Record 1 of Set 15 | bani
# Processing Record 2 of Set 15 | portobelo
# Processing Record 3 of Set 15 | san cristobal
# Processing Record 4 of Set 15 | soe
# Processing Record 5 of Set 15 | osypenko
# Processing Record 6 of Set 15 | santo antonio do leverger
# Processing Record 7 of Set 15 | talakan
# Processing Record 8 of Set 15 | hobyo
# Processing Record 9 of Set 15 | hai phong
# City not found. Skipping...
# Processing Record 10 of Set 15 | strezhevoy
# Processing Record 11 of Set 15 | jutai
# Processing Record 12 of Set 15 | anzio
# Processing Record 13 of Set 15 | longa
# Processing Record 14 of Set 15 | sarakhs
# Processing Record 15 of Set 15 | ubauro
# Processing Record 16 of Set 15 | manjacaze
# Processing Record 17 of Set 15 | bellevue
# Processing Record 18 of Set 15 | zaysan
# Processing Record 19 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 15 | karasuyama
# Processing Record 21 of Set 15 | maltahohe
# Processing Record 22 of Set 15 | mogadishu
# Processing Record 23 of Set 15 | nadym
# Processing Record 24 of Set 15 | askarovo
# Processing Record 25 of Set 15 | boueni
# Processing Record 26 of Set 15 | zlatoustovsk
# City not found. Skipping...
# Processing Record 27 of Set 15 | ibiruba
# Processing Record 28 of Set 15 | vezirkopru
# Processing Record 29 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 15 | mercedes
# Processing Record 31 of Set 15 | santiago del estero
# Processing Record 32 of Set 15 | bhimunipatnam
# Processing Record 33 of Set 15 | mecca
# Processing Record 34 of Set 15 | grenville
# Processing Record 35 of Set 15 | gordeyevka
# Processing Record 36 of Set 15 | vanimo
# Processing Record 37 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 38 of Set 15 | malaryta
# Processing Record 39 of Set 15 | cacota
# Processing Record 40 of Set 15 | viransehir
# Processing Record 41 of Set 15 | venado tuerto
# Processing Record 42 of Set 15 | harer
# Processing Record 43 of Set 15 | kampot
# Processing Record 44 of Set 15 | okakarara
# Processing Record 45 of Set 15 | casino
# Processing Record 46 of Set 15 | payo
# Processing Record 47 of Set 15 | teya
# Processing Record 48 of Set 15 | marsh harbour
# Processing Record 49 of Set 15 | matcha
# Processing Record 50 of Set 15 | keti bandar
# Processing Record 1 of Set 16 | crotone
# Processing Record 2 of Set 16 | phangnga
# Processing Record 3 of Set 16 | odweyne
# Processing Record 4 of Set 16 | kananga
# Processing Record 5 of Set 16 | borama
# City not found. Skipping...
# Processing Record 6 of Set 16 | marand
# Processing Record 7 of Set 16 | margate
# Processing Record 8 of Set 16 | gillette
# Processing Record 9 of Set 16 | tha chang
# Processing Record 10 of Set 16 | kalat
# Processing Record 11 of Set 16 | puqi
# Processing Record 12 of Set 16 | hami
# Processing Record 13 of Set 16 | mumford
# Processing Record 14 of Set 16 | namatanai
# Processing Record 15 of Set 16 | varzea alegre
# Processing Record 16 of Set 16 | bengkalis
# City not found. Skipping...
# Processing Record 17 of Set 16 | preobrazheniye
# Processing Record 18 of Set 16 | mokhsogollokh
# Processing Record 19 of Set 16 | rolla
# Processing Record 20 of Set 16 | waddan
# Processing Record 21 of Set 16 | taylorville
# Processing Record 22 of Set 16 | ewa beach
# Processing Record 23 of Set 16 | santa luzia
# Processing Record 24 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 16 | angra dos reis
# Processing Record 26 of Set 16 | belmonte
# Processing Record 27 of Set 16 | belyy yar
# Processing Record 28 of Set 16 | jiuquan
# Processing Record 29 of Set 16 | coahuayana
# Processing Record 30 of Set 16 | vestbygda
# City not found. Skipping...
# Processing Record 31 of Set 16 | clearwater
# Processing Record 32 of Set 16 | dubenskiy
# City not found. Skipping...
# Processing Record 33 of Set 16 | mmabatho
# Processing Record 34 of Set 16 | ust-kalmanka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 721

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Mahebourg      MU -20.4081   57.7000     75.25        56
# 1  Aleksandrovskiy Zavod      RU  50.9237  117.9374     22.15        74
# 2              Jamestown      US  42.0970  -79.2353     35.19        91
# 3                Kahului      US  20.8947 -156.4700     80.62        69
# 4                 Albany      US  42.6001  -73.9662     31.46        76
# 5                  Vaini      TO -21.2000 -175.2000     77.16        94
# 6            Provideniya      RU  64.3833 -173.3000     30.36        69
# 7                Ushuaia      AR -54.8000  -68.3000     46.06        87
# 8          Bambanglipuro      ID  -7.9500  110.2833     83.79        72
# 9                Mataura      NZ -46.1927  168.8643     70.39        56
#
#    Cloudiness  Wind Speed Current Description
# 0          40        8.05    scattered clouds
# 1          82        7.27       broken clouds
# 2         100        4.61     overcast clouds
# 3          40       14.97    scattered clouds
# 4          21        4.34          few clouds
# 5          40        5.75             drizzle
# 6         100       22.37     overcast clouds
# 7          75        4.61       broken clouds
# 8         100        2.86     overcast clouds
# 9          99        2.04     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df= city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head()

# Recreate the DataFrame by using the new column order
city_data_df = pd.DataFrame(city_data)

# Display sample data
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Mahebourg      MU -20.4081   57.7000     75.25        56
# 1  Aleksandrovskiy Zavod      RU  50.9237  117.9374     22.15        74
# 2              Jamestown      US  42.0970  -79.2353     35.19        91
# 3                Kahului      US  20.8947 -156.4700     80.62        69
# 4                 Albany      US  42.6001  -73.9662     31.46        76
# 5                  Vaini      TO -21.2000 -175.2000     77.16        94
# 6            Provideniya      RU  64.3833 -173.3000     30.36        69
# 7                Ushuaia      AR -54.8000  -68.3000     46.06        87
# 8          Bambanglipuro      ID  -7.9500  110.2833     83.79        72
# 9                Mataura      NZ -46.1927  168.8643     70.39        56
#
#    Cloudiness  Wind Speed Current Description
# 0          40        8.05    scattered clouds
# 1          82        7.27       broken clouds
# 2         100        4.61     overcast clouds
# 3          40       14.97    scattered clouds
# 4          21        4.34          few clouds
# 5          40        5.75             drizzle
# 6         100       22.37     overcast clouds
# 7          75        4.61       broken clouds
# 8         100        2.86     overcast clouds
# 9          99        2.04     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
